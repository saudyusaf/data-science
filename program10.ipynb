# %% [markdown]
# <a href="https://colab.research.google.com/github/saudyusaf/data-science/blob/main/program10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data = {'Name':['Tom', 'nick', 'krish', 'jack'],'Age':[20, 21, 19, 18]}
df = pd.DataFrame(data) # Convert the dictionary into DataFram
print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
'Age':[27, 24, 22, 32],
'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
df = pd.DataFrame(data)
print(df[['Name', 'Qualification']])
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
data1 = pd.read_csv("/content/Emp-Data.csv", encoding="latin1")
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   First Name           184 non-null    object
#  1   Gender               184 non-null    object
#  2   Joining Date         184 non-null    object
#  3   Band                 184 non-null    object
#  4   Total Experience     184 non-null    object
#  5   Annual Salary        184 non-null    int64
#  6   Certified            184 non-null    bool
#  7   Domain               184 non-null    object
#  8   Client/Accounts      184 non-null    object
#  9   Revenue in Millions  184 non-null    int64
#  10  Company Branches     184 non-null    object
#  11  Client Since         184 non-null    int64
#  12  Country              184 non-null    object
# dtypes: bool(1), int64(3), object(9)
# memory usage: 17.6+ KB

# %%
data1.head()
# Out:
#   First Name  Gender Joining Date Band Total Experience  Annual Salary  \
# 0  Employe-1    Male     8/6/2024   5A              2.6         295818
# 1  Employe-2    Male    3/31/1996   5A                3         292162
# 2  Employe-3  Female    4/23/1993   5A              1.2         258371
# 3  Employe-4    Male     3/4/2005   5A              2.6         295145
# 4  Employe-5    Male    1/24/1998   5A              2.9         274099
#
#    Certified        Domain  Client/Accounts  Revenue in Millions  \
# 0       True       Banking    Bank of China                  117
# 1       True  Construction  Larsen & Toubro                  103
# 2      False  Construction      DLF Limited                  111
# 3       True     Insurance       State Farm                  111
# 4       True          fmcg              HUL                  139
#
#   Company Branches  Client Since      Country
# 0        Bangalore          1982        India
# 1          Chennai          2018           UK
# ...

# %%
first = data1.head()
print(first)
# Out:
#   First Name  Gender Joining Date Band Total Experience  Annual Salary  \
# 0  Employe-1    Male     8/6/2024   5A              2.6         295818
# 1  Employe-2    Male    3/31/1996   5A                3         292162
# 2  Employe-3  Female    4/23/1993   5A              1.2         258371
# 3  Employe-4    Male     3/4/2005   5A              2.6         295145
# 4  Employe-5    Male    1/24/1998   5A              2.9         274099
#
#    Certified        Domain  Client/Accounts  Revenue in Millions  \
# 0       True       Banking    Bank of China                  117
# 1       True  Construction  Larsen & Toubro                  103
# 2      False  Construction      DLF Limited                  111
# 3       True     Insurance       State Farm                  111
# 4       True          fmcg              HUL                  139
#
#   Company Branches  Client Since      Country
# 0        Bangalore          1982        India
# 1          Chennai          2018           UK
# ...

# %%
arr=np.array([10,15,18,22])
s = pd.Series(arr)
print(s)
# Out:
# 0    10
# 1    15
# 2    18
# 3    22
# dtype: int64

# %%
arr1=np.array(['a','b','c','d'])
s1=pd.Series(arr, index=['first','second','third','fourth'])
print(s1)
# Out:
# first     10
# second    15
# third     18
# fourth    22
# dtype: int64

# %%
s2=pd.Series(50, index=[0, 1, 2, 3, 4])
print (s2)
# Out:
# 0    50
# 1    50
# 2    50
# 3    50
# 4    50
# dtype: int64

# %%
d={'Name': 'Farsan', 'Class' : 'MCA', 'year' : 2024}
s3=pd.Series(d)
print(s3)
# Out:
# Name     Farsan
# Class       MCA
# year       2024
# dtype: object

# %%
s4 = pd.Series([10,15,18,22])
df=pd.DataFrame(s4)
df.columns=['List1']
df['List2']=20
df['List3']=df['List1']+df['List2']
print(df)
# Out:
#    List1  List2  List3
# 0     10     20     30
# 1     15     20     35
# 2     18     20     38
# 3     22     20     42

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
values = np.random.randn(100)
s5 = pd.Series(values) # generate a pandas series
print("series\n",s5)
s5.plot(kind='hist', title='Normally distributed random values')
plt.show()
# Out:
# series
#  0     1.764052
# 1     0.400157
# 2     0.978738
# 3     2.240893
# 4     1.867558
#         ...
# 95    0.706573
# 96    0.010500
# 97    1.785870
# 98    0.126912
# 99    0.401989
# Length: 100, dtype: float64

# %%
s5.describe()
# Out:
# count    100.000000
# mean       0.059808
# std        1.012960
# min       -2.552990
# 25%       -0.643857
# 50%        0.094096
# 75%        0.737077
# max        2.269755
# dtype: float64

# %%
df = pd.DataFrame({'A': [1, 2, 1, 4, 3],
'B': [12, 14, 11, 16, 18],
'C': ['a', 'a', 'b', 'a', 'b']})
df
# Out:
#    A   B  C
# 0  1  12  a
# 1  2  14  a
# 2  1  11  b
# 3  4  16  a
# 4  3  18  b

# %%
df.describe()
# Out:
#              A          B
# count  5.00000   5.000000
# mean   2.20000  14.200000
# std    1.30384   2.863564
# min    1.00000  11.000000
# 25%    1.00000  12.000000
# 50%    2.00000  14.000000
# 75%    3.00000  16.000000
# max    4.00000  18.000000

# %%
iris = pd.read_csv('/content/Iris.csv')
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = pd.DataFrame(pd.read_csv("/content/Iris.csv"))
df.hist()
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
iris['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
data3 = pd.read_csv ('/content/california_housing_test.csv')
data3.info()
data3.describe()
data3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# ...

# %%
import seaborn as sns
data4 = sns.load_dataset('tips')

sns.scatterplot(x='total_bill', y='tip', data=data4)
plt.title('Scatter Plot of Total Bill vs. Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Load Housing Price dataset
data = pd.read_csv ('/content/california_housing_test.csv')
# Scatter Plot
plt.figure(figsize=(10, 8))
sns.scatterplot(x='median_house_value', y='housing_median_age',
data=data)
plt.title('Scatter Plot for Median House Value vs. Housing Median Age')
plt.xlabel('Median House Value')
plt.ylabel('Housing Median Age')
plt.show()
